# %% [markdown]
# # MAPs to Brazil States
# ### Developed by Manuel Robalinho
# ### Set/2018

# %%
# Map Sources:
# https://gadm.org/download_country_v3.html
# Using GeoPandas

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import geopandas as gpd

# %%
path = 'ML/GeoPandas/Brazil/'

# %%
# Tables Brasil and states
uf_br0 = gpd.read_file(path + 'shp/gadm36_BRA_0.shp')
uf_br1 = gpd.read_file(path + 'shp/gadm36_BRA_1.shp')

# %%
# Tables Brasil Distritos and municipios
uf_br2 = gpd.read_file(path + 'shp/gadm36_BRA_2.shp')
uf_br3 = gpd.read_file(path + 'shp/gadm36_BRA_3.shp')

# %%
# BRASIL
uf_br0
# Out:
#   GID_0  NAME_0                                           geometry
# 0   BRA  Brazil  (POLYGON ((-52.07069397 -32.0284729, -52.07069...

# %%
# Statues - UF  BRAZIL
uf_br1
# Out:
#    GID_0  NAME_0     GID_1               NAME_1             VARNAME_1  \
# 0    BRA  Brazil   BRA.1_1                 Acre                  None
# 1    BRA  Brazil   BRA.2_1              Alagoas                  None
# 2    BRA  Brazil   BRA.3_1                Amapá                  None
# 3    BRA  Brazil   BRA.4_1             Amazonas               Amazone
# 4    BRA  Brazil   BRA.5_1                Bahia                  Ba¡a
# 5    BRA  Brazil   BRA.6_1                Ceará                  None
# 6    BRA  Brazil   BRA.7_1     Distrito Federal                  None
# 7    BRA  Brazil   BRA.8_1       Espírito Santo        Espiritu Santo
# 8    BRA  Brazil   BRA.9_1                Goiás           Goiáz|Goyáz
# 9    BRA  Brazil  BRA.10_1             Maranhão  São Luíz de Maranhão
# 10   BRA  Brazil  BRA.12_1          Mato Grosso          Matto Grosso
# 11   BRA  Brazil  BRA.11_1   Mato Grosso do Sul                  None
# 12   BRA  Brazil  BRA.13_1         Minas Gerais    Minas|Minas Geraes
# 13   BRA  Brazil  BRA.14_1                 Pará                  None
# 14   BRA  Brazil  BRA.15_1              Paraíba              Parahyba
# 15   BRA  Brazil  BRA.16_1               Paraná                  None
# 16   BRA  Brazil  BRA.17_1           Pernambuco            Pernambouc
# 17   BRA  Brazil  BRA.18_1                Piauí                Piauhy
# 18   BRA  Brazil  BRA.19_1       Rio de Janeiro                  None
# 19   BRA  Brazil  BRA.20_1  Rio Grande do Norte                  None
# 20   BRA  Brazil  BRA.21_1    Rio Grande do Sul                  None
# 21   BRA  Brazil  BRA.22_1             Rondônia               Guaporé
# 22   BRA  Brazil  BRA.23_1              Roraima            Rio Branco
# 23   BRA  Brazil  BRA.24_1       Santa Catarina       Santa Catharina
# 24   BRA  Brazil  BRA.25_1            São Paulo                  None
# 25   BRA  Brazil  BRA.26_1              Sergipe                  None
# 26   BRA  Brazil  BRA.27_1            Tocantins                  None
#
#    NL_NAME_1            TYPE_1         ENGTYPE_1  CC_1 HASC_1  \
# 0       None            Estado             State  None  BR.AC
# 1       None            Estado             State  None  BR.AL
# 2       None            Estado             State  None  BR.AP
# 3       None            Estado             State  None  BR.AM
# 4       None            Estado             State  None  BR.BA
# 5       None            Estado             State  None  BR.CE
# 6       None  Distrito Federal  Federal District  None  BR.DF
# 7       None            Estado             State  None  BR.ES
# 8       None            Estado             State  None  BR.GO
# 9       None            Estado             State  None  BR.MA
# 10      None            Estado             State  None  BR.MT
# 11      None            Estado             State  None  BR.MS
# 12      None            Estado             State  None  BR.MG
# 13      None            Estado             State  None  BR.PA
# 14      None            Estado             State  None  BR.PB
# 15      None            Estado             State  None  BR.PR
# 16      None            Estado             State  None  BR.PE
# 17      None            Estado             State  None  BR.PI
# 18      None            Estado             State  None  BR.RJ
# 19      None            Estado             State  None  BR.RN
# 20      None            Estado             State  None  BR.RS
# 21      None            Estado             State  None  BR.RO
# 22      None            Estado             State  None  BR.RR
# 23      None            Estado             State  None  BR.SC
# 24      None            Estado             State  None  BR.SP
# 25      None            Estado             State  None  BR.SE
# 26      None            Estado             State  None  BR.TO
#
#                                              geometry
# 0   POLYGON ((-68.10552979000001 -10.72191715, -68...
# 1   (POLYGON ((-35.88986206 -9.844305990000001, -3...
# 2   (POLYGON ((-50.82569504 2.522084, -50.82569504...
# 3   POLYGON ((-58.13698959 -7.35613918, -58.136821...
# 4   (POLYGON ((-38.69208145 -17.95958328, -38.6920...
# 5   (POLYGON ((-40.83180618 -2.8812499, -40.831806...
# 6   POLYGON ((-47.93915176 -16.05134773, -48.02110...
# 7   (POLYGON ((-40.88402939 -21.16124916, -40.8840...
# 8   POLYGON ((-49.0048027 -18.53718185, -49.012477...
# 9   (POLYGON ((-44.54986191 -1.88458395, -44.54986...
# 10  POLYGON ((-52.47142792 -16.12672043, -52.48841...
# 11  POLYGON ((-54.16836166 -23.99920082, -54.17062...
# 12  POLYGON ((-50.84402084 -19.9675808, -50.853321...
# 13  (POLYGON ((-47.29791641 -0.63375098, -47.29791...
# 14  (POLYGON ((-43.01207733 -9.408011439999999, -4...
# 15  (POLYGON ((-48.36513901 -25.73402786, -48.3651...
# 16  (POLYGON ((-35.13597107 -8.83791733, -35.13597...
# 17  POLYGON ((-42.69078445 -9.54547024, -42.691215...
# 18  (POLYGON ((-44.67124939 -23.35458374, -44.6712...
# 19  (POLYGON ((-35.10958481 -6.1937499, -35.109584...
# 20  (POLYGON ((-52.07069397 -32.0284729, -52.07069...
# 21  POLYGON ((-62.89218903 -12.86013603, -62.89211...
# 22  POLYGON ((-60.0378952 0.26348999, -60.04676437...
# 23  (POLYGON ((-48.54236221 -27.93180466, -48.5423...
# 24  (POLYGON ((-48.08235931 -25.28430557, -48.0823...
# 25  (POLYGON ((-37.38458252 -11.45985985, -37.3845...
# 26  POLYGON ((-49.23736191 -12.88397312, -49.23532...

# %%
# Municipios
uf_br2.head()
# Out:
#   GID_0  NAME_0    GID_1 NAME_1 NL_NAME_1      GID_2        NAME_2 VARNAME_2  \
# 0   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.1_1    Acrelândia      None
# 1   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.2_1  Assis Brazil      None
# 2   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.3_1     Brasiléia      None
# 3   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.4_1        Bujari      None
# 4   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.5_1      Capixaba      None
#
#   NL_NAME_2     TYPE_2     ENGTYPE_2  CC_2 HASC_2  \
# 0      None  Município  Municipality  None   None
# 1      None  Município  Municipality  None   None
# 2      None  Município  Municipality  None   None
# 3      None  Município  Municipality  None   None
# 4      None  Município  Municipality  None   None
#
#                                             geometry
# 0  POLYGON ((-67.16084290000001 -9.98259926000000...
# 1  POLYGON ((-69.56517792 -10.95549774, -69.56603...
# 2  POLYGON ((-69.4235611 -10.92717266, -69.419380...
# 3  POLYGON ((-67.94033813 -9.33721924, -67.944107...
# 4  POLYGON ((-68.00377655 -10.65377045, -68.00351...

# %%
# Distritos
uf_br3.head()
# Out:
#   GID_0  NAME_0    GID_1 NAME_1 NL_NAME_1      GID_2        NAME_2 NL_NAME_2  \
# 0   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.1_1    Acrelândia      None
# 1   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.2_1  Assis Brazil      None
# 2   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.3_1     Brasiléia      None
# 3   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.4_1        Bujari      None
# 4   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.5_1      Capixaba      None
#
#          GID_3        NAME_3 VARNAME_3 NL_NAME_3    TYPE_3 ENGTYPE_3  CC_3  \
# 0  BRA.1.1.1_1    Acrelândia      None      None  Distrito  District  None
# 1  BRA.1.2.1_1  Assis Brazil      None      None  Distrito  District  None
# 2  BRA.1.3.1_1     Brazileia      None      None  Distrito  District  None
# 3  BRA.1.4.1_1        Bujari      None      None  Distrito  District  None
# 4  BRA.1.5.1_1      Capixaba      None      None  Distrito  District  None
#
#   HASC_3                                           geometry
# 0   None  POLYGON ((-67.16084289550781 -9.98259925842285...
# 1   None  POLYGON ((-69.56517791748047 -10.9554977416992...
# 2   None  POLYGON ((-69.42356109619141 -10.9271726608275...
# 3   None  POLYGON ((-67.94033813476557 -9.33721923828125...
# 4   None  POLYGON ((-68.00377655029297 -10.6537704467773...

# %%
uf_br1.plot(cmap='YlOrRd')

# %%
# List of states - UF
uf_br1x = uf_br1[['NAME_1', 'geometry']]
uf_br1x
# Out:
#                  NAME_1                                           geometry
# 0                  Acre  POLYGON ((-68.10552979000001 -10.72191715, -68...
# 1               Alagoas  (POLYGON ((-35.88986206 -9.844305990000001, -3...
# 2                 Amapá  (POLYGON ((-50.82569504 2.522084, -50.82569504...
# 3              Amazonas  POLYGON ((-58.13698959 -7.35613918, -58.136821...
# 4                 Bahia  (POLYGON ((-38.69208145 -17.95958328, -38.6920...
# 5                 Ceará  (POLYGON ((-40.83180618 -2.8812499, -40.831806...
# 6      Distrito Federal  POLYGON ((-47.93915176 -16.05134773, -48.02110...
# 7        Espírito Santo  (POLYGON ((-40.88402939 -21.16124916, -40.8840...
# 8                 Goiás  POLYGON ((-49.0048027 -18.53718185, -49.012477...
# 9              Maranhão  (POLYGON ((-44.54986191 -1.88458395, -44.54986...
# 10          Mato Grosso  POLYGON ((-52.47142792 -16.12672043, -52.48841...
# 11   Mato Grosso do Sul  POLYGON ((-54.16836166 -23.99920082, -54.17062...
# 12         Minas Gerais  POLYGON ((-50.84402084 -19.9675808, -50.853321...
# 13                 Pará  (POLYGON ((-47.29791641 -0.63375098, -47.29791...
# 14              Paraíba  (POLYGON ((-43.01207733 -9.408011439999999, -4...
# 15               Paraná  (POLYGON ((-48.36513901 -25.73402786, -48.3651...
# 16           Pernambuco  (POLYGON ((-35.13597107 -8.83791733, -35.13597...
# 17                Piauí  POLYGON ((-42.69078445 -9.54547024, -42.691215...
# 18       Rio de Janeiro  (POLYGON ((-44.67124939 -23.35458374, -44.6712...
# 19  Rio Grande do Norte  (POLYGON ((-35.10958481 -6.1937499, -35.109584...
# 20    Rio Grande do Sul  (POLYGON ((-52.07069397 -32.0284729, -52.07069...
# 21             Rondônia  POLYGON ((-62.89218903 -12.86013603, -62.89211...
# 22              Roraima  POLYGON ((-60.0378952 0.26348999, -60.04676437...
# 23       Santa Catarina  (POLYGON ((-48.54236221 -27.93180466, -48.5423...
# 24            São Paulo  (POLYGON ((-48.08235931 -25.28430557, -48.0823...
# 25              Sergipe  (POLYGON ((-37.38458252 -11.45985985, -37.3845...
# 26            Tocantins  POLYGON ((-49.23736191 -12.88397312, -49.23532...

# %%
# Transform POLYGON to POINT
# copy poly to new GeoDataFrame
points = uf_br1x.copy()
# change the geometry
points.geometry = points['geometry'].centroid
# same crs
#points.crs = poly.crs
points.head()
# Out:
#      NAME_1                                       geometry
# 0      Acre  POINT (-70.44666617524693 -9.309916735880247)
# 1   Alagoas   POINT (-36.62319561662706 -9.51555361360583)
# 2     Amapá   POINT (-51.96103309015383 1.440043429560412)
# 3  Amazonas  POINT (-64.71488057979415 -4.186776806608581)
# 4     Bahia  POINT (-41.73007712980874 -12.47331113316648)

# %%
# PLOT State points
f, ax = plt.subplots(1, figsize=(8,10))
ax.set_axis_on()
f.suptitle('BRAZIL')
# Plot the states area
ax = uf_br1x.plot(ax=ax, facecolor='blue', alpha=1, linewidth=0, cmap='YlOrRd')

# Plot the labels 
for x, y, label in zip(points.geometry.x, points.geometry.y, points.NAME_1):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), alpha=3, textcoords="offset points",color='blue')

# %%
# Plot Base Country ans states
ax.figsize=(8,10)
# Plot the states area
base = uf_br1x.plot( edgecolor='black', cmap='OrRd')
# Plot Base continent - Cities
ax = uf_br1x.plot(ax=base, facecolor='blue', alpha=1, linewidth=0,  cmap='OrRd')

# Plot Base continent - Cities
for x, y, label in zip(points.geometry.x, points.geometry.y, points.NAME_1):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points",color='green')

# %%
uf_br2.head()
# Out:
#   GID_0  NAME_0    GID_1 NAME_1 NL_NAME_1      GID_2        NAME_2 VARNAME_2  \
# 0   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.1_1    Acrelândia      None
# 1   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.2_1  Assis Brazil      None
# 2   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.3_1     Brasiléia      None
# 3   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.4_1        Bujari      None
# 4   BRA  Brazil  BRA.1_1   Acre      None  BRA.1.5_1      Capixaba      None
#
#   NL_NAME_2     TYPE_2     ENGTYPE_2  CC_2 HASC_2  \
# 0      None  Município  Municipality  None   None
# 1      None  Município  Municipality  None   None
# 2      None  Município  Municipality  None   None
# 3      None  Município  Municipality  None   None
# 4      None  Município  Municipality  None   None
#
#                                             geometry
# 0  POLYGON ((-67.16084290000001 -9.98259926000000...
# 1  POLYGON ((-69.56517792 -10.95549774, -69.56603...
# 2  POLYGON ((-69.4235611 -10.92717266, -69.419380...
# 3  POLYGON ((-67.94033813 -9.33721924, -67.944107...
# 4  POLYGON ((-68.00377655 -10.65377045, -68.00351...

# %%
# CEARA - UF
uf_br1_ce = uf_br1[uf_br1.GID_1 == 'BRA.6_1']
uf_br1_ce
# Out:
#   GID_0  NAME_0    GID_1 NAME_1 VARNAME_1 NL_NAME_1  TYPE_1 ENGTYPE_1  CC_1  \
# 5   BRA  Brazil  BRA.6_1  Ceará      None      None  Estado     State  None
#
#   HASC_1                                           geometry
# 5  BR.CE  (POLYGON ((-40.83180618 -2.8812499, -40.831806...

# %%
# MAP Of CEARA - Filter UF
# Statues - UF  BRAZIL
uf_br2_ce = uf_br2[uf_br2.GID_1 == 'BRA.6_1']

# %%
uf_br2_ce.head(10)
# Out:
#     GID_0  NAME_0    GID_1 NAME_1 NL_NAME_1       GID_2             NAME_2  \
# 615   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.1_1            Abaiara
# 616   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.2_1            Acarapé
# 617   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.3_1             Acaraú
# 618   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.4_1           Acopiara
# 619   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.5_1             Aiuaba
# 620   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.6_1         Alcântaras
# 621   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.7_1          Altaneira
# 622   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.8_1         Alto Santo
# 623   BRA  Brazil  BRA.6_1  Ceará      None   BRA.6.9_1           Amontada
# 624   BRA  Brazil  BRA.6_1  Ceará      None  BRA.6.10_1  Antonina do Norte
#
#     VARNAME_2 NL_NAME_2     TYPE_2     ENGTYPE_2  CC_2 HASC_2  \
# 615      None      None  Município  Municipality  None   None
# 616      None      None  Município  Municipality  None   None
# 617      None      None  Município  Municipality  None   None
# 618      None      None  Município  Municipality  None   None
# 619      None      None  Município  Municipality  None   None
# 620      None      None  Município  Municipality  None   None
# 621      None      None  Município  Municipality  None   None
# 622      None      None  Município  Municipality  None   None
# 623      None      None  Município  Municipality  None   None
# 624      None      None  Município  Municipality  None   None
#
#                                               geometry
# 615  POLYGON ((-38.99930573 -7.31215, -38.98537445 ...
# 616  POLYGON ((-38.6201973 -4.25379992, -38.6841697...
# 617  (POLYGON ((-39.99142456 -3.23660398, -40.00414...
# 618  POLYGON ((-39.49590683 -6.33128881, -39.502334...
# 619  POLYGON ((-40.33156967 -6.80437183, -40.342914...
# 620  POLYGON ((-40.50021744 -3.6300149, -40.4937553...
# 621  POLYGON ((-39.68080902 -7.01779509, -39.690811...
# 622  POLYGON ((-38.24853897 -5.64724112, -38.264713...
# 623  POLYGON ((-39.8677597 -3.45082688, -39.8951606...
# 624  POLYGON ((-39.91426468 -6.76730919, -39.939926...

# %%
# List of Cities from UF
uf_br2x = uf_br2_ce[['NAME_2', 'geometry']]
uf_br2x.head()
# Out:
#        NAME_2                                           geometry
# 615   Abaiara  POLYGON ((-38.99930573 -7.31215, -38.98537445 ...
# 616   Acarapé  POLYGON ((-38.6201973 -4.25379992, -38.6841697...
# 617    Acaraú  (POLYGON ((-39.99142456 -3.23660398, -40.00414...
# 618  Acopiara  POLYGON ((-39.49590683 -6.33128881, -39.502334...
# 619    Aiuaba  POLYGON ((-40.33156967 -6.80437183, -40.342914...

# %%
# Transform POLYGON to POINT
# copy poly to new GeoDataFrame
points = uf_br2x.copy()
# change the geometry
points.geometry = points['geometry'].centroid

points.head()
# Out:
#        NAME_2                                       geometry
# 615   Abaiara  POINT (-39.03744666881347 -7.360263034220808)
# 616   Acarapé  POINT (-38.66316186615578 -4.222426778424921)
# 617    Acaraú   POINT (-40.08873728909125 -2.96786068805975)
# 618  Acopiara  POINT (-39.49275273464827 -6.122398590402195)
# 619    Aiuaba  POINT (-40.29881732797426 -6.605116010704714)

# %%
# PLOT Municipios from UF
f, ax = plt.subplots(1, figsize=(12,14))
ax.set_axis_on()
f.suptitle('BRAZIL - CEARA')
# Plot the states area
ax = uf_br1_ce.plot(ax=ax, facecolor='blue', alpha=1, linewidth=0, cmap='YlOrRd')

# Plot the labels 
for x, y, label in zip(points.geometry.x, points.geometry.y, points.NAME_2):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), alpha=3, textcoords="offset points",color='blue')

# %%
# PLOT Municipios from UF
f, ax = plt.subplots(1, figsize=(12,14))
ax.set_axis_on()
f.suptitle('BRAZIL - CEARA')
# Plot the states area
ax = uf_br2x.plot(ax=ax, facecolor='cy', alpha=0.5, linewidth=1)

# Plot the labels 
for x, y, label in zip(points.geometry.x, points.geometry.y, points.NAME_2):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), alpha=3, textcoords="offset points",color='blue')

# %%
# PLOT Municipios from UF
f, ax = plt.subplots(1, figsize=(12,14))
ax.set_axis_on()
f.suptitle('BRAZIL - CEARA')
# Plot the states area
ax = uf_br2x.plot(ax=ax, facecolor='blue', alpha=0.2, linewidth=0, cmap='YlOrRd')

# Plot the labels 
for x, y, label in zip(points.geometry.x, points.geometry.y, points.NAME_2):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), alpha=3, textcoords="offset points",color='blue')
